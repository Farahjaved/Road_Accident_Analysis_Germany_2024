# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
# Define path
path = r'C:\Users\muham\OneDrive\Desktop\careerfoundry\Data Immersion\Achievement 6\05-10-25 Accident_data_germany_2024_analysis'

# %%
# Import Data
df_merged_new = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_merged_new.csv'), low_memory= False)

# %%
df_merged_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268519 entries, 0 to 268518
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0.2                   268519 non-null  int64
#  1   Unnamed: 0.1                   268519 non-null  int64
#  2   Unnamed: 0                     268519 non-null  int64
#  3   OID_                           268519 non-null  int64
#  4   accident_id                    268519 non-null  object
#  5   state                          268519 non-null  int64
#  6   administrative_region          268519 non-null  int64
#  7   administrative_district        268519 non-null  int64
#  8   municipality                   268519 non-null  int64
#  9   year_of_accident               268519 non-null  int64
#  10  month_of_accident              268519 non-null  int64
#  11  hour_of_accident               268519 non-null  int64
#  12  day_of_week                    268519 non-null  int64
#  13  accident_category              268519 non-null  int64
#  14  collision_type                 268519 non-null  int64
#  15  accident_behavior_type         268519 non-null  int64
#  16  light_conditions               268519 non-null  int64
#  17  road_surface_conditions        268519 non-null  int64
#  18  accident_with_bicycle          268519 non-null  int64
#  19  accident_with_pessenger_car    268519 non-null  int64
#  20  accident_with_pedestrian       268519 non-null  int64
#  21  accident_with_motorcycle       268519 non-null  int64
#  22  involving_heavy_goods_vehicle  268519 non-null  int64
#  23  other_vehicle_involved         268519 non-null  int64
#  24  UTM_X                          268519 non-null  float64
#  25  UTM_Y                          268519 non-null  float64
#  26  Longitude_WGS84                268519 non-null  float64
#  27  Latitude_WGS84                 268519 non-null  float64
#  28  location_check_level           268519 non-null  int64
#  29  state_name                     268519 non-null  object
#  30  population                     268519 non-null  int64
#  31  accidents_in_state             268519 non-null  int64
#  32  accidents_per_100k             268519 non-null  float64
#  33  light_condition_label          268519 non-null  object
#  34  road_condition_label           268519 non-null  object
# dtypes: float64(5), int64(26), object(4)
# memory usage: 71.7+ MB

# %%
df_merged_new = df_merged_new.drop(columns = ['Unnamed: 0.2','Unnamed: 0.1', 'Unnamed: 0'])

# %%
# Mapping codes for better understanding 
accident_behaviour_labels = {
    1: "Driving Error",
    2: "Turn-Off Accident",
    3: "Turn/Cross Collision",
    4: "Pedestrian/Road Crossing",
    5: "Stationary Collision",
    6: "Same-Direction Collision",
    7: "Other"
}


df_merged_new['accident_behaviour_label'] = df_merged_new['accident_behavior_type'].map(accident_behaviour_labels)

# %%
# exporting data frame
df_merged_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'df_merged_new.csv'))
